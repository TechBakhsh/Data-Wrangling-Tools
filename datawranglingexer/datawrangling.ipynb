# %% [markdown]
# # Data Wrangling

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as  plt
import seaborn as sns

# %%
titanic=sns.load_dataset("titanic")
titanic
tt1=titanic
tt2=titanic

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#simple opration
(titanic["age"]+2).head(10)
# Out:
# 0    24.0
# 1    40.0
# 2    28.0
# 3    37.0
# 4    37.0
# 5     NaN
# 6    56.0
# 7     4.0
# 8    29.0
# 9    16.0
# Name: age, dtype: float64

# %%
# missing values
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# use dropna method for missing values
titanic.dropna(subset=["deck"], axis=0, inplace=True)
titanic.shape
# Out:
# (203, 15)

# %%
titanic.isnull().sum()
# Out:
# survived        0
# pclass          0
# sex             0
# age            19
# sibsp           0
# parch           0
# fare            0
# embarked        2
# class           0
# who             0
# adult_male      0
# deck            0
# embark_town     2
# alive           0
# alone           0
# dtype: int64

# %%
#titanic=titanic.dropna()

titanic=titanic.dropna()
titanic.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
titanic.shape
# Out:
# (182, 15)

# %%
tt1.isnull().sum()
# Out:
# survived        0
# pclass          0
# sex             0
# age            19
# sibsp           0
# parch           0
# fare            0
# embarked        2
# class           0
# who             0
# adult_male      0
# deck            0
# embark_town     2
# alive           0
# alone           0
# dtype: int64

# %% [markdown]
# # Replacing mising values with the average of that columns

# %%
#finding an average (mean)
# mtlb k ham missing value bhi average k through change kr sakty han aur dropna k through bhi
mean = tt1["age"].mean()
mean
# Out:
# 35.77945652173913

# %%
#replacing nan with mean of the data (updating as well)
tt1["age"]=tt1["age"].replace(np.nan, mean)

# %%
tt1.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
# know the data type
titanic.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
# use this method to convert data type from one format to another 
titanic["survived"]=titanic["survived"].astype("float64")
titanic.dtypes
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# survived        float64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
# here we will convert the age into days instead of years
titanic["age"]=titanic["age"]*365
titanic.head(10)
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     survived  pclass     sex      age  sibsp  parch      fare embarked  \
# 1        1.0       1  female  13870.0      1      0   71.2833        C
# 3        1.0       1  female  12775.0      1      0   53.1000        S
# 6        0.0       1    male  19710.0      0      0   51.8625        S
# 10       1.0       3  female   1460.0      1      1   16.7000        S
# 11       1.0       1  female  21170.0      0      0   26.5500        S
# 21       1.0       2    male  12410.0      0      0   13.0000        S
# 23       1.0       1    male  10220.0      0      0   35.5000        S
# ...

# %%
# always rename afterwards
titanic.rename(columns={"age":"age in days"}, inplace=True)
titanic.head()
# Out:
# c:\Users\HP\Desktop\python\lib\site-packages\pandas\core\frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#     survived  pclass     sex  age in days  sibsp  parch     fare embarked  \
# 1        1.0       1  female      13870.0      1      0  71.2833        C
# 3        1.0       1  female      12775.0      1      0  53.1000        S
# 6        0.0       1    male      19710.0      0      0  51.8625        S
# 10       1.0       3  female       1460.0      1      1  16.7000        S
# 11       1.0       1  female      21170.0      0      0  26.5500        S
#
#     class    who  adult_male deck  embark_town alive  alone
# 1   First  woman       False    C    Cherbourg   yes  False
# 3   First  woman       False    C  Southampton   yes  False
# ...

# %%
#tt4=tt1

# %% [markdown]
# # Data Normalization

# %%
titanic.head()

# %%
titanic=titanic[["age in days", 'fare']]
titanic.head()

# %% [markdown]
# # Method of Normalization

# %%
#simple feature scalling
titanic["fare"]=titanic["fare"]/titanic["fare"].max()
titanic.head()
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     survived  pclass     sex  age in days  sibsp  parch      fare embarked  \
# 1        1.0       1  female      13870.0      1      0  0.139136        C
# 3        1.0       1  female      12775.0      1      0  0.103644        S
# 6        0.0       1    male      19710.0      0      0  0.101229        S
# 10       1.0       3  female       1460.0      1      1  0.032596        S
# 11       1.0       1  female      21170.0      0      0  0.051822        S
#
#     class    who  adult_male deck  embark_town alive  alone
# 1   First  woman       False    C    Cherbourg   yes  False
# ...

# %%
#simple feature scalling
titanic["age in days"]=titanic["age in days"]/titanic["fare"].max()
titanic.head()
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     survived  pclass     sex  age in days  sibsp  parch      fare embarked  \
# 1        1.0       1  female      13870.0      1      0  0.139136        C
# 3        1.0       1  female      12775.0      1      0  0.103644        S
# 6        0.0       1    male      19710.0      0      0  0.101229        S
# 10       1.0       3  female       1460.0      1      1  0.032596        S
# 11       1.0       1  female      21170.0      0      0  0.051822        S
#
#     class    who  adult_male deck  embark_town alive  alone
# 1   First  woman       False    C    Cherbourg   yes  False
# ...

# %%
# min and max method
titanic["fare"]=(titanic["fare"]-titanic["fare"].min())/titanic["fare"]-titanic["fare"].min()
titanic.head()
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     survived  pclass     sex  age in days  sibsp  parch  fare embarked  class  \
# 1        1.0       1  female      13870.0      1      0   1.0        C  First
# 3        1.0       1  female      12775.0      1      0   1.0        S  First
# 6        0.0       1    male      19710.0      0      0   1.0        S  First
# 10       1.0       3  female       1460.0      1      1   1.0        S  Third
# 11       1.0       1  female      21170.0      0      0   1.0        S  First
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# ...

# %%
#z-score (standard score)
titanic["fare"]=(titanic["fare"]-titanic["fare"].mean())/titanic["fare"].std()
titanic.head()
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     survived  pclass     sex  age in days  sibsp  parch  fare embarked  class  \
# 1        1.0       1  female      13870.0      1      0   NaN        C  First
# 3        1.0       1  female      12775.0      1      0   NaN        S  First
# 6        0.0       1    male      19710.0      0      0   NaN        S  First
# 10       1.0       3  female       1460.0      1      1   NaN        S  Third
# 11       1.0       1  female      21170.0      0      0   NaN        S  First
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# ...

# %%
# log transformation
titanic["fare"]=np.log(titanic["fare"])
titanic.head()
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     survived  pclass     sex  age in days  sibsp  parch  fare embarked  class  \
# 1        1.0       1  female      13870.0      1      0   NaN        C  First
# 3        1.0       1  female      12775.0      1      0   NaN        S  First
# 6        0.0       1    male      19710.0      0      0   NaN        S  First
# 10       1.0       3  female       1460.0      1      1   NaN        S  Third
# 11       1.0       1  female      21170.0      0      0   NaN        S  First
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# ...

# %% [markdown]
# # converting categories into dummies
# * Easy to use of computation
# - male female (0,1)

# %%
pd.get_dummies(titanic["fare"])
titanic.head()
# Out:
#     survived  pclass     sex  age in days  sibsp  parch  fare embarked  class  \
# 1        1.0       1  female      13870.0      1      0   NaN        C  First
# 3        1.0       1  female      12775.0      1      0   NaN        S  First
# 6        0.0       1    male      19710.0      0      0   NaN        S  First
# 10       1.0       3  female       1460.0      1      1   NaN        S  Third
# 11       1.0       1  female      21170.0      0      0   NaN        S  First
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# 3   woman       False    C  Southampton   yes  False
# 6     man        True    E  Southampton    no   True
# 10  child       False    G  Southampton   yes  False
# 11  woman       False    C  Southampton   yes   True
